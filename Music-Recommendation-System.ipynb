# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./music.csv')
data
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# ...

# %%
data.isnull().sum()
# Out:
# Song-Name          0
# Singer/Artists    10
# Genre              0
# Album/Movie        3
# User-Rating        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2407 entries, 0 to 2419
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Song-Name       2407 non-null   object
#  1   Singer/Artists  2407 non-null   object
#  2   Genre           2407 non-null   object
#  3   Album/Movie     2407 non-null   object
#  4   User-Rating     2407 non-null   object
# dtypes: object(5)
# memory usage: 112.8+ KB

# %%
data.duplicated().sum()
# Out:
# 16

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (2391, 5)

# %%
data.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %%
lst = [] # Taking the point values in the list
for i in data['User-Rating']:
    lst.append(i[:3])
lst
# Out:
# ['8.8',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.2',
#  '9.1',
#  '9.2',
#  '9.5',
#  '9.2',
#  '9.6',
#  '8.8',
#  '8.4',
#  '9.1',
#  '9.2',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '9.2',
#  '9.2',
#  '9.5',
#  '8.6',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.2',
#  '9.5',
#  '9.4',
#  '8.7',
#  '9.3',
#  '9.3',
#  '9.5',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '8.4',
#  '8.4',
#  '8.8',
#  '9.2',
#  '9.2',
#  '9.6',
#  '9.6',
#  '9.0',
#  '9.1',
#  '8.5',
#  '9.5',
#  '8.5',
#  '9.7',
#  '8.9',
#  '9.6',
#  '8.5',
#  '9.1',
#  '8.7',
#  '8.6',
#  '9.3',
#  '9.7',
#  '8.9',
#  '9.0',
#  '9.0',
#  '9.3',
#  '9.3',
#  '9.1',
#  '9.0',
#  '9.7',
#  '9.2',
#  '9.1',
#  '9.0',
#  '8.9',
#  '9.5',
#  '9.5',
#  '9.7',
#  '9.0',
#  '8.1',
#  '8.1',
#  '9.5',
#  '9.1',
#  '8.6',
#  '9.4',
#  '9.0',
#  '9.0',
#  '9.6',
#  '9.3',
#  '9.0',
#  '9.2',
#  '9.3',
#  '9.1',
#  '8.6',
#  '9.5',
#  '9.5',
#  '9.0',
#  '9.4',
#  '9.2',
#  '9.6',
#  '9.3',
#  '7.7',
#  '9.2',
#  '9.3',
# ...

# %%
data.loc[:,'User-Rating'] = lst
# Out:
# C:\Users\amay\anaconda3\lib\site-packages\pandas\core\indexing.py:1843: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
data.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba         8.8
# 1  BollywoodDanceRomantic    Luka Chuppi         9.0
# 2          BollywoodDance      Gully Boy         9.7
# 3          BollywoodDance  Total Dhamaal         9.1
# 4       BollywoodRomantic         Simmba         9.2

# %%
data['Album/Movie'] = data['Album/Movie'].str.replace(' ', '')
data['Singer/Artists'] = data['Singer/Artists'].str.replace(' ','')
data.head()
# Out:
# <ipython-input-72-31837a3dab4b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Album/Movie'] = data['Album/Movie'].str.replace(' ', '')
# <ipython-input-72-31837a3dab4b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Singer/Artists'] = data['Singer/Artists'].str.replace(' ','')
#           Song-Name                             Singer/Artists  \
# 0       Aankh Marey             KumarSanu,MikaSingh,NehaKakkar
# 1         Coca Cola                      NehaKakkar,TonyKakkar
# ...

# %%
data['Singer/Artists'] = data['Singer/Artists'].str.replace(',',' ')
# Out:
# <ipython-input-73-95da658f5b05>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Singer/Artists'] = data['Singer/Artists'].str.replace(',',' ')

# %%
data.head()
# Out:
#           Song-Name                             Singer/Artists  \
# 0       Aankh Marey             KumarSanu MikaSingh NehaKakkar
# 1         Coca Cola                      NehaKakkar TonyKakkar
# 2  Apna Time Aayega                               RanveerSingh
# 3            Mungda          JyoticaTangri Shaan SubhroGanguly
# 4          Tere Bin  AseesKaur RahatFatehAliKhan TanishkBagchi
#
#                     Genre   Album/Movie User-Rating
# 0          BollywoodDance        Simmba         8.8
# 1  BollywoodDanceRomantic    LukaChuppi         9.0
# 2          BollywoodDance      GullyBoy         9.7
# 3          BollywoodDance  TotalDhamaal         9.1
# 4       BollywoodRomantic        Simmba         9.2

# %%
data['tags'] = data['Singer/Artists'] + ' ' + data['Genre'] + ' '+data['Album/Movie'] + ' ' +data['User-Rating']
data['tags']
# Out:
# <ipython-input-75-50266755b5ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['tags'] = data['Singer/Artists'] + ' ' + data['Genre'] + ' '+data['Album/Movie'] + ' ' +data['User-Rating']
# 0       KumarSanu MikaSingh NehaKakkar BollywoodDance ...
# 1       NehaKakkar TonyKakkar BollywoodDanceRomantic L...
# 2                RanveerSingh BollywoodDance GullyBoy 9.7
# 3       JyoticaTangri Shaan SubhroGanguly BollywoodDan...
# 4       AseesKaur RahatFatehAliKhan TanishkBagchi Boll...
#                               ...
# 2415                    Mukesh BollywoodDance Sasural 6.2
# 2416    LataMangeshkar BollywoodDance JabPyarKisiSeHot...
# 2417    LataMangeshkar SureshWadkar BollywoodDance Lam...
# ...

# %%
newData = data[['Song-Name', 'tags']]
newData
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# 0     KumarSanu MikaSingh NehaKakkar BollywoodDance ...
# 1     NehaKakkar TonyKakkar BollywoodDanceRomantic L...
# 2              RanveerSingh BollywoodDance GullyBoy 9.7
# 3     JyoticaTangri Shaan SubhroGanguly BollywoodDan...
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi Boll...
# ...                                                 ...
# 2415                  Mukesh BollywoodDance Sasural 6.2
# ...

# %%
newData['tags'] = newData['tags'].apply(lambda x: x.lower())
newData
# Out:
# <ipython-input-77-8691066c53dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newData['tags'] = newData['tags'].apply(lambda x: x.lower())
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2000)

# %%
vectors = cv.fit_transform(newData['tags']).toarray()

# %%
vectors.shape
# Out:
# (2391, 1697)

# %%
cv.get_feature_names()
# Out:
# ['13',
#  '1920',
#  '1921',
#  '1947',
#  '2states',
#  '3dev',
#  '3idiots',
#  '3storeys',
#  '55',
#  '7ekterasaath',
#  '7khoonmaaf',
#  '7welcometolondon',
#  '9211',
#  'aadesh',
#  'aagalelagjaa',
#  'aah',
#  'aajamerijaan',
#  'aajanachle',
#  'aakankshasharma',
#  'aakhirkyon',
#  'aakhreeraasta',
#  'aamantrikha',
#  'aamir',
#  'aan',
#  'aanchalsethi',
#  'aandhi',
#  'aaniya',
#  'aankhen',
#  'aapkaasurroor',
#  'aapkikasam',
#  'aapkikhatir',
#  'aapsemausiiquii',
#  'aaryandineshkanagaratnam',
#  'aashayein',
#  'aashiqbanayaaapne',
#  'aashiqui',
#  'aashiqui2',
#  'aashqui2',
#  'aaskapanchhi',
#  'aasthagill',
#  'aazaan',
#  'abcd',
#  'abcd2',
#  'abhaydeol',
#  'abhayjodhpurkar',
#  'abhijeet',
#  'abhijeetsawant',
#  'abhijitvaghani',
#  'abhimaan',
#  'abhisheknailwal',
#  'abhisheknehwal',
#  'actionjackson',
#  'actionreplayy',
#  'actorinlaw',
#  'aditipaul',
#  'aditisinghsharma',
#  'aditsinghsharma',
#  'adityan',
#  'adityanarayan',
#  'adnansami',
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
sim = cosine_similarity(vectors)

# %%
sim[0]
# Out:
# array([1.        , 0.2236068 , 0.25819889, ..., 0.2236068 , 0.25819889,
#        0.25819889])

# %%
def recommend(music):
    musicIndex = newData[newData['Song-Name'] == music].index[0]
    distances = sim[musicIndex]
    musicList = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:6]
    for i in musicList:
        print(newData.iloc[i[0]]['Song-Name'])

# %%
recommend('Tere Bin')
# Out:
# Sanu Ek Pal Chain
# Jag Ghoomeya
# Nit Khair Manga
# Lag Ja Gale
# Nazar Se Nazar Mile

# %%
import pickle
pickle.dump(newData, open('musicrec.pkl', 'wb'))

# %%
pickle.dump(sim, open('similarities.pkl', 'wb'))
